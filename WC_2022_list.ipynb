# %%
url = "https://en.wikipedia.org/wiki/FIFA_World_Cup_top_goalscorers"

# %%
import pandas as pd
tables = pd.read_html(url)
len(tables)
# Out:
# 3

# %%
df = tables[0]
df
# Out:
#     Rank                   Player  Goals  Apps  Ratio  First  Last  \
# 0      1          Alan Shearer[b]    260   441   0.59   1992  2006
# 1      2             Wayne Rooney    208   491   0.42   2002  2018
# 2      3               Harry Kane    195   297   0.66   2012  2022
# 3      4                Andy Cole    187   414   0.45   1993  2006
# 4      5            Sergio Agüero    184   275   0.67   2011  2021
# 5      6            Frank Lampard    177   609   0.29   1996  2015
# 6      7            Thierry Henry    175   258   0.68   1999  2012
# 7      8            Robbie Fowler    163   379   0.43   1993  2008
# 8      9            Jermain Defoe    162   496   0.33   2001  2018
# 9     10             Michael Owen    150   326   0.46   1997  2013
# 10    11         Les Ferdinand[b]    149   351   0.42   1992  2004
# 11    12      Teddy Sheringham[b]    146   418   0.35   1992  2006
# 12    13         Robin van Persie    144   280   0.51   2004  2015
# ...

# %%
df.to_csv("top_scorers.csv", index=False)
